# %% [markdown]
# # Assignment 10

# %% [markdown]
# ### 1.复习上课内容

# %% [markdown]
# ### 2. 回答一下理论题目

# %% [markdown]
# #### 1. What is independent assumption in Naive bayes ?

# %% [markdown]
# 利用贝叶斯定理求解联合概率P(XY)时，需要计算条件概率P(X|Y)。在计算P(X|Y)时，朴素贝叶斯做了一个很强的条件独立假设（当Y确定时，X的各个分量取值之间相互独立），即P(X1=x1,X2=x2,...Xj=xj|Y=yk) = P(X1=x1|Y=yk)*P(X2=x2|Y=yk)*...*P(Xj=xj|Y=yk)。

# %% [markdown]
# #### 2. What is MAP(maximum a posterior) and ML(maximum likelihood) ?

# %%
MAP：最大后验概率
ML：最大似然估计

# %% [markdown]
# #### 3. What is support vector in SVM?

# %% [markdown]
# 距离超平面最近的点为支持向量

# %% [markdown]
# #### 4. What is the intuition behind SVM ?

# %% [markdown]
# 可以看到这个数据是线性可分的，即存在一条直线把正负样本分开，且这里存在有多条不同的直线可以把正负样本分开。支持向量机会选择图中黑色的这条线来作为决策边界，相对于其他的线来看要更合理些。从数学上来讲，这条黑线和训练样本之间有着更大的最短距离，这个距离被称作支持向量机的间距，这是支持向量机具有鲁棒性的原因，因为它努力用一个最大间距来分离样本。因此SVM经常被称作是一种大间距分类器（Large Margin Intuition）。

# %% [markdown]
# #### 5. Shortly describ what 'random' means in random forest ?

# %% [markdown]
# 森林中的每棵树的按照如下规则生成：
# 1. 如果训练集大小为N，对于每棵树而言，随机且有放回地从训练集中的抽取N个训练样本（这种采样方式称为bootstrap sample方法），作为该树的训练集；
# 从这里我们可以知道：每棵树的训练集都是不同的，而且里面包含重复的训练样本（理解这点很重要）。

# %% [markdown]
# #### 6. What cariterion does XGBoost use to find the best split point in a tree ?

# %% [markdown]
# 第一种“Exact Greedy Algorithm for Split Finding”，是一种利用穷举法选择最佳的分裂节点
# 第二种“Approximate Algorithm for Split Finding”，通过加权分位数方法近似选择最佳的分裂节点
# 第三种“Sparsity-aware Split Finding”，针对稀疏特征的分裂点选择法

# %% [markdown]
# ### 3. Practial part

# %% [markdown]
# ##### Problem description: In this part you are going to build a classifier to detect if a piece of news is published by the Xinhua news agency (新华社）.

# %% [markdown]
# #### Hints:

# %% [markdown]
# ###### 1. Firstly, you have to come up with a way to represent the news. (Vectorize the sentence, you can find different ways to do so online)

# %%
import text2vec
a = '如何更换花呗绑定银行卡'
emb = text2vec.encode(a)
print(a, emb)
# Out:
# [  DEBUG 20200327 10:06:39 word_embedding:82] load w2v embedding ...
# [  DEBUG 20200327 10:06:44 word_embedding:110] load w2v from C:\Users\Administrator\.text2vec\datasets\light_Tencent_AILab_ChineseEmbedding.bin, spend 5.143294095993042 s
# [  DEBUG 20200327 10:06:44 word_embedding:134] word count   : 143617
# [  DEBUG 20200327 10:06:44 word_embedding:135] emb size     : 200
# [  DEBUG 20200327 10:06:44 word_embedding:136] Top 50 word  : ['的', ',', '了', '“', '”', '是', '在', '和', '我', '有', '就', '也', '.', '你', '他', '都', '我们', '可以', '上', '一个', '啊', '与', '她', '个', '自己', '就是', '对', '这', '~', '为', '这个', '?', '还是', '等', '吗', '而', '到', '但', '将', '被', '没有', '他们', '-', '中', '但是', '吧', '从', '已经', '要', '呢']
# 如何更换花呗绑定银行卡 [ 4.71473746e-02 -1.22305989e-01 -2.12236792e-02  3.39640975e-02
#   3.26218940e-02  2.51194951e-03 -9.80294216e-03  3.33396234e-02
#  -2.46070325e-02  6.95534423e-02 -5.89465210e-03  3.96882705e-02
#   3.10125891e-02 -1.78968478e-02  1.63691619e-03 -1.47556812e-02
# ...

# %%
#!dir 新华社数据
import pandas as pd
doc=pd.read_csv("新华社数据/新华社数据.csv",encoding='GB18030')
doc.head()
# Out:
#       id      author                  source  \
# 0  89617         NaN  快科技@http://www.kkj.cn/
# 1  89616         NaN  快科技@http://www.kkj.cn/
# 2  89615         NaN  快科技@http://www.kkj.cn/
# 3  89614         NaN                     新华社
# 4  89613  胡淑丽_MN7479                   深圳大件事
#
#                                              content  \
# 0  此外，自本周（6月12日）起，除小米手机6等15款机型外，其余机型已暂停更新发布（含开发版/...
# 1  骁龙835作为唯一通过Windows 10桌面平台认证的ARM处理器，高通强调，不会因为只考...
# 2  此前的一加3T搭载的是3400mAh电池，DashCharge快充规格为5V/4A。\r\n...
# 3    这是6月18日在葡萄牙中部大佩德罗冈地区拍摄的被森林大火烧毁的汽车。新华社记者张立云摄\r\n
# 4  （原标题：44岁女子跑深圳约会网友被拒，暴雨中裸身奔走……）\r\n@深圳交警微博称：昨日清...
#
#                                              feature  \
# 0  {"type":"科技","site":"cnbeta","commentNum":"37"...
# 1  {"type":"科技","site":"cnbeta","commentNum":"15"...
# 2  {"type":"科技","site":"cnbeta","commentNum":"18"...
# 3  {"type":"国际新闻","site":"环球","commentNum":"0","j...
# 4  {"type":"新闻","site":"网易热门","commentNum":"978",...
#
#                            title  \
# ...

# %%
from math import isnan
import math
TOKEN =[]
articles=[]
for i in doc.content:
    articles.append(i)
print(len(articles))    
embs=[]
i=0
len_articles=len(articles)
print(len_articles)
#print(articles[0])
#print(type(articles[0]))
#print(articles[99])
#print(type(articles[100]))
#print(articles[101])
for i in range(len_articles):
    if pd.isnull(articles[i]):
        print(i)
        continue
    embs.append(text2vec.encode(articles[i]))
# Out:
# 89611
# 89611
# 100
# 103
# 997
# 1273
# 1282
# 1434
# 2593
# 3003
# 4631
# 4754
# 4781
# 4784
# 4787
# 4791
# 4793
# 4837
# 4839
# 4843
# 4856
# 4873
# 4874
# 4877
# 4880
# 4892
# 4898
# 4918
# 5092
# 5096
# 5098
# 5101
# 5105
# 5134
# 5654
# 5660
# 5681
# 5779
# 5788
# 5860
# 5890
# 5948
# 5957
# 5964
# 5972
# 5979
# 6034
# 6053
# 6078
# 6093
# 6096
# 6231
# 6240
# 6249
# 6285
# 6337
# 6385
# 6453
# 6457
# 6525
# 6541
# 6582
# 6588
# 6609
# 6647
# 6676
# 6680
# 6685
# 6759
# 6807
# 6815
# 6910
# 6963
# 6970
# 7117
# 7134
# 7382
# 7481
# 7792
# 7825
# 7831
# 7851
# 7890
# 7946
# 8003
# 8009
# 8077
# 8080
# 8081
# 8082
# 8083
# 8084
# 8085
# 8086
# 8087
# 8088
# 8089
# 8090
# 8091
# 8092
# 8093
# 8094
# 8095
# 8096
# 8097
# 8098
# 8099
# 8100
# 8101
# 8102
# 8103
# 8104
# 8105
# 8106
# 8107
# 8108
# 8109
# 8110
# 8111
# 8112
# 8113
# 8114
# 8115
# 8116
# 8117
# 8118
# 8119
# 8120
# 8121
# 8122
# 8123
# 8124
# 8125
# 8126
# 8127
# 8128
# 8129
# 8130
# 8131
# 8132
# 8133
# 8134
# 8135
# ...

# %%
print(embs[0])
# Out:
# [ 4.47741561e-02 -5.76452911e-02 -3.49147618e-02  8.07185993e-02
#   4.03056368e-02  7.76003813e-03  1.32755851e-02  4.96378951e-02
#   2.64788121e-02  6.20893389e-02 -2.19049677e-02  1.71033219e-02
#   6.36400562e-03 -5.39097330e-03 -5.72015857e-03 -1.53307505e-02
#   8.29460938e-03 -6.34342656e-02 -2.44544260e-02 -4.23974171e-02
#  -3.82750891e-02  2.39890181e-02 -1.99230667e-03  4.47160415e-02
#   3.95223498e-02  2.25269366e-02 -4.80127148e-02  5.36043867e-02
#   2.15577129e-02 -1.38219311e-05  2.38129292e-02  3.02014239e-02
#   3.42817395e-03  3.81113105e-02 -2.63125952e-02 -5.15083857e-02
#   6.90790787e-02  3.80794480e-02 -6.55061081e-02 -9.62302461e-03
#   1.70792453e-02  1.72180291e-02  1.40839770e-01  6.13010004e-02
#  -2.28665639e-02 -1.59280207e-02 -7.48149380e-02 -1.56475887e-01
#   9.64780431e-03 -3.04841492e-02 -7.02685043e-02 -9.56187025e-03
#  -6.66425824e-02  4.53576781e-02  2.33766250e-02 -8.66933353e-03
# ...

# %%
from text2vec import Similarity
a = '如何更换花呗绑定银行卡'
b = '花呗更改绑定银行卡'
sim = Similarity()
s = sim.get_score(a, b)
print(s)
# Out:
# [  DEBUG 20200327 10:28:50 word_embedding:82] load w2v embedding ...
# [  DEBUG 20200327 10:28:56 word_embedding:110] load w2v from C:\Users\Administrator\.text2vec\datasets\light_Tencent_AILab_ChineseEmbedding.bin, spend 5.628321647644043 s
# [  DEBUG 20200327 10:28:56 word_embedding:134] word count   : 143617
# [  DEBUG 20200327 10:28:56 word_embedding:135] emb size     : 200
# [  DEBUG 20200327 10:28:56 word_embedding:136] Top 50 word  : ['的', ',', '了', '“', '”', '是', '在', '和', '我', '有', '就', '也', '.', '你', '他', '都', '我们', '可以', '上', '一个', '啊', '与', '她', '个', '自己', '就是', '对', '这', '~', '为', '这个', '?', '还是', '等', '吗', '而', '到', '但', '将', '被', '没有', '他们', '-', '中', '但是', '吧', '从', '已经', '要', '呢']
# 0.937504730299001

# %% [markdown]
# ###### 2. Secondly,  pick a machine learning algorithm that you think is suitable for this task

# %% [markdown]
# ### Congratulations! You have completed all assignments in this week. The question below is optional. If you still have time, why don't try it out.

# %% [markdown]
# ## Option:

# %% [markdown]
# #### Try differnt machine learning algorithms with different combinations of parameters in the practical part, and compare their performances (Better use some visualization techiniques).
